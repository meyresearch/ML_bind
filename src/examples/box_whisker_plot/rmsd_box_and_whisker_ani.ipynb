# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
raw_rmsd= pd.read_csv("rmsd_results_ani.csv")

# %%
sns.set_theme(style="whitegrid")

# %%
colours={"AMBER_ejm_31":"steelblue", "ANI_ejm_31":"firebrick","AMBER_ejm_42":"steelblue", "ANI_ejm_42":"firebrick","AMBER_ejm_43":"steelblue", "ANI_ejm_43":"firebrick","AMBER_ejm_44":"steelblue", "ANI_ejm_44":"firebrick","AMBER_ejm_46":"steelblue", "ANI_ejm_46":"firebrick","AMBER_ejm_48":"steelblue", "ANI_ejm_48":"firebrick","AMBER_ejm_55":"steelblue", "ANI_ejm_55":"firebrick","AMBER_jmc_28":"steelblue", "ANI_jmc_28":"firebrick"}

# %%
plt.figure(figsize=(30,15))
plt.rc('xtick',labelsize=26)
plt.rc('ytick',labelsize=32)
plt.xlabel("Ligand", size=40, labelpad=20)
plt.xticks(rotation=45, ha="right")
plt.ylabel("RMSD (nm)", size= 40, labelpad=20)
rmsd=sns.boxplot(x=raw_rmsd["Ligand"], y=raw_rmsd["RMSD (nm)"], width=0.75, fliersize=10, linewidth=4, palette=colours)
plt.tight_layout()
plt.savefig("rmsd_box_whisker_ani.png")
